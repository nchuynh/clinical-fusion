# %% [markdown]
# # Team 70
#
# **Team members:** Nhan Huynh (nchuynh2@illinois.edu)
#
# **Paper:** [10] Combining structured and unstructured data for predictive models: a deep learning approach
#
# **GitHub repository:** https://github.com/nchuynh/clinical-fusion
#
# **Video presentation:** https://www.youtube.com/watch?v=tBxqkE2sRhs

# %% [markdown]
# # Introduction
#
# ## Background of the problem
# * **What type of problem: disease/readmission/mortality prediction,  feature engineering, data processing, etc**
#   * The type of problem is feature engineering and prediction of patient mortality, length of stay, and unplanned hospital readmission. The authors state that unstructured clinicals notes were not being used for these predictive tasks.
# * **What is the importance/meaning of solving the problem**
#   * This problem is important for developing deep learning models that can leverage electronic health records (EHRs) for improving patient outcomes. The insights from these predictive tasks can help healthcare professionals identify patients that need additional focus.
# * **What is the difficulty of the problem**
#   * This problem is difficult because EHRs contain unstructured clinical notes that are not easy to featurize. The sequential nature of these notes can also present challenges.
# * **The state of the art methods and effectiveness**
#   * At the time, the state of the art utilized traditional logistic regression and random forest models as well asl recurrent neural networks (RNNs). These have been relatively successful at predicting clinical outcomes. Caruana [2] used logistic regression and random forest models to predict hospital readmission with > 0.7 AUC. Tran [3] used RNNs and temporal physiologic features to predict patient mortality with > 0.9 AUC.
#
# ## Paper explanation
# * **What did the paper propose**
#   * The paper proposed 2 approaches that contained either convolutional layers (Fusion-CNN) or LSTM layers (Fusion-LSTM) for creating features from the unstructured clinical notes and the temporal signals. The clinical notes are converted into embeddings using Doc2Vec before being featurized by the convolutional or LSTM layers. For each patient, features are generated from the clinical notes, temporal signals, and static information. Then the features are concatenated into a single patient feature and used for outcome prediction.
# * **What is the innovations of the method**
#   * The innovation of this method is that it creates embeddings from the unstructured clinical notes and uses every component from the EHRs in the patient representation for outcome prediction.
# * **How well the proposed method work (in its own metrics)**
#   * For each of the predictive tasks (mortality, long length of stay, and readmission) using all of the data modalities (notes, temporal signals, and static information), the Fusion-CNN and the Fusion-LSTM models perform better than the baseline models (logistic regression and random forest). For mortality prediction and readmission prediction, Fusion-LSTM performs the best with an AUROC of 0.871 and 0.674 respectively. For long length of stay prediction, Fusion-CNN performs the best with an AUROC of 0.784.
# * **What is the contribution to the research regime (referring the Background above, how important the paper is to the problem)**
#   * This paper is important to the problem because it demonstrates that every component of the EHRs (including unstructured clinical notes) can be used to improve model performance on healthcare predictive tasks. The authors demonstrate that these models perform better than baseline models.

# %% [markdown]
# # Scope of Reproducibility
#
# **List hypotheses from the paper you will test and the corresponding experiments you will run.**
#
# 1.   Hypothesis 1: The deep models (Fusion-CNN and Fusion-LSTM) perform better than baseline models (logistic regression and random forest) on the predictive tasks (mortality, long length of stay, and readmission).
# 2.   Hypothesis 2: Models trained using all of the data modalities from EHRs (unstructured notes, temporal signs, and static information) will perform better on the predictive tasks than models trained on only structured data (temporal signs and static information).
#
# All of the models will be trained and evaluated on EHRs from the MIMIC-III dataset. Each of the predictive tasks will be binary classification problems and the evaluation metric will be AUROC. Ablation experiments will be run by training models without the unstructured clinical notes.

# %% [markdown]
# # Methodology

# %% [markdown]
# ## Environment

# %% [markdown]
# **Requirements:**
# * Python = 3.6.10
# * Gensim = 3.8.0
# * Matplotlib = 3.1.3
# * NLTK = 3.4.5
# * Numpy = 1.14.2
# * Pandas = 0.25.3
# * Scikit-learn = 0.20.1
# * Tqdm = 4.42.1
# * PyTorch = 1.4.0

# %%
# Create Conda environment using requirements.yml
# conda env create -f environment.yml

# Activate clinical-fusion Conda environment
# conda activate clinical-fusion

# %%
# import packages

import os
import sys
import time
import json
import random
import argparse
from glob import glob
from collections import OrderedDict
from collections import Counter
import subprocess

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from gensim.models.doc2vec import Doc2Vec

import torch
from torch.autograd import Variable
from torch.backends import cudnn
from torch.nn import DataParallel
from torch.utils.data import DataLoader

# import main_helper
# import data_loader
# import lstm, cnn
import myloss
import function
from utils import cal_metric, get_ids, text2words

sys.path.append('./tools')
import py_op

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##  Data
#
# * **Source of the data:**
#   * The source of the data is the Medical Information Mart for Intensive Cre III (MIMIC-III) dataset. It was collected by the Massachusetts Institute of Technology (MIT)'s Laboratory for Computational Physiology from over 40,000 patients that stayed in critical care units at Beth Israel Deaconess Medical Center (BIDMC) between 2001 and 2012. The dataset includes deidentified patient health information such as clinical notes, vital signs, lab test results, medications, diagnosis codes, and demographics.
#
# * **Statistics:**
#   * The total size of the dataset is 39427 admissions. For in-hospital mortality, 3771 (9.6%) are labeled yes and 35658 (90.4%) are labeled no. For 30-day readmission, 2237 (5.7%) are labeled yes and 37192 (94.3%) are labeled no. For long length of stay, 19689 (49.9%) are labeled yes and 19740 (50.1%) are labeled no. The dataset is split into 70% for training, 10% for validation, and 20% for testing.
#
# * **Data process:**
#   * The data is pre-processed to remove all patients with age less than 18 years old and all hospital admissions with lengths shorter than 1 day. Patients with missing temporal signals and clinical notes were removed too. Binary labels were assigned for each predictive task. For readmission, the threshold is 30 days and for long length of stay, the threshold is 7 days. A Doc2Vec model is trained on the training set to generate document-level embeddings for each clinical note using Gensim. A script is used to split the dataset to train/valid/test. Additional scripts are used to prepare the data for input into the baseline and deep learning models.

# %% [markdown]
# ## Data preprocessing
#
# 1. Request access to MIMIC-III dataset by:
#   * Creating a PhysioNet account on: `https://physionet.org/login/`
#   * Completing the training for CITI Data or Specimens Only research: `https://physionet.org/about/citi-course/`
#   * Submitting the training completion certificate: `https://physionet.org/settings/training/`
#   * Signing the data use agreement: `https://physionet.org/sign-dua/mimiciii/1.4/`
#   * Becoming a credentialed user: `https://physionet.org/settings/credentialing/`
#
#
# 2. Download the files for the MIMIC-III dataset
#
#
# 3. Place the files in: `./data/mimic`
#
#
# 4. Create a MIMIC-III database using PostgreSQL by:
#   * Downloading and installing PostgreSQL: `http://www.postgresql.org/download/`
#   * Cloning the mimic-code repo:
#     * `git clone https://github.com/MIT-LCP/mimic-code.git`
#   * Making the database from the MIMIC-III files:
#     * `make create-user mimic-gz datadir="/path/to/mimic-iii-clinical-database-1.4/"`
#
#
# 5. Run SQL queries and export views by:
#   * Connecting to the MIMIC-III database:
#     * `psql -d mimic`
#   * Setting the default scheme to mimiciii:
#     * `SET search_path TO mimiciii;`
#   * Executing the .sql files in `./query` and exporting the views to .csv files:
#     ```
#     \i adm_details.sql
#     \copy (SELECT * FROM adm_details) TO 'adm_details.csv' WITH CSV HEADER;
#
#     \i pivoted-lab.sql
#     \copy (SELECT * FROM pivoted_lab) TO 'pivoted-lab.csv' WITH CSV HEADER;
#
#     \i pivoted-vital.sql
#     \copy (SELECT * FROM pivoted_vital) TO 'pivoted-vital.csv' WITH CSV HEADER;
#     ```
#   * Transferring the .csv files to `./data/mimic`
#
#
# 6. Run the preproessing scripts with:
#    ```
#    python 00_define_cohort.py # define patient cohort and collect labels
#    python 01_get_signals.py # extract temporal signals (vital signs and laboratory tests)
#    python 02_extract_notes.py --firstday # extract first day clinical notes
#    python 03_merge_ids.py # merge admission IDs
#    python 04_statistics.py # run statistics
#    python 05_preprocess.py # run preprocessing
#    python 06_doc2vec.py --phase train # train doc2vec model
#    python 06_doc2vec.py --phase infer # infer doc2vec vectors
#    ```

# %%
raw_data_dir = './data/mimic/'
processed_data_dir = './data/processed/'

def load_data(processed_data_dir):
    # load patient ids
    train_ids, val_ids, test_ids = get_ids(f'{processed_data_dir}files/splits.json')
    list_ids = train_ids + val_ids + test_ids
    df = pd.read_csv(f'{processed_data_dir}mortality.csv').sort_values('hadm_id')
    ids_patient = np.intersect1d(list_ids, df['hadm_id'].tolist())
    
    # load processed clinical notes
    vector_dict = json.load(open(f'{processed_data_dir}files/vector_dict.json'))
    data_notes = np.array([np.mean(vector_dict.get(adm_id, []), axis=0) for adm_id in ids_patient])
    
    # load processed temporal signals
    df_temporal = pd.read_csv(f'{processed_data_dir}/features.csv').drop('charttime', axis=1)
    temporal_mm_dict = json.load(open(f'{processed_data_dir}/files/feature_mm_dict.json'))
    for col in df_temporal.columns[1:]:
        col_min, col_max = temporal_mm_dict[col]
        df_temporal[col] = (df_temporal[col] - col_min) / (col_max - col_min)
    df_temporal = df_temporal.groupby('hadm_id').agg(['mean', 'count', 'max', 'min', 'std'])
    df_temporal.columns = ['_'.join(col).strip() for col in df_temporal.columns.values]
    df_temporal.fillna(0, inplace=True)
    df_temporal = df_temporal.reset_index().sort_values('hadm_id')
    df_temporal_cols = df_temporal.columns[1:]
    data_temporal = df_temporal[df_temporal_cols].to_numpy()
    
    # load processed demographics data
    demo_json = json.load(open(f'{processed_data_dir}/files/demo_dict.json'))
    data_demographics = pd.DataFrame(demo_json.items(), columns=['hadm_id', 'demos']).sort_values('hadm_id')
    
    return data_notes, data_temporal, data_demographics

data_notes, data_temporal, data_demographics = load_data(processed_data_dir)

def load_labels(processed_data_dir):
    # load labels for in-hospital mortality
    labels_mortality = pd.read_csv(f'{processed_data_dir}/mortality.csv').sort_values('hadm_id')
    
    # load labels for 30-day readmission
    labels_readmission = pd.read_csv(f'{processed_data_dir}/readmit.csv').sort_values('hadm_id')

    # load labels for long length of stay
    labels_length = pd.read_csv(f'{processed_data_dir}/llos.csv').sort_values('hadm_id')

    return labels_mortality, labels_readmission, labels_length

labels_mortality, labels_readmission, labels_length = load_labels(processed_data_dir)

def calculate_stats_data(data, input_name):
    shape_data = data.shape
    print(f'Number of inputs for {input_name}: {shape_data[0]}')
    print(f'Length of feature for {input_name}: {shape_data[1]}')

calculate_stats_data(data_notes, 'Clinical Notes')
calculate_stats_data(data_temporal, 'Temporal Signals')
calculate_stats_data(data_demographics, 'Demographics Information')

def calculate_stats_labels(label, label_name):
    print(f'Counts of labels for {label_name}: {dict(Counter(label[label.columns[1]]))}')
    return dict(Counter(label[label.columns[1]]))

counts_mortality = calculate_stats_labels(labels_mortality, 'In-Hospital Mortality')
counts_readmission = calculate_stats_labels(labels_readmission, '30-Day Readmission')
counts_length = calculate_stats_labels(labels_length, 'Long Length of Stay')
# Out:
# Number of inputs for Clinical Notes: 39427
# Length of feature for Clinical Notes: 200
# Number of inputs for Temporal Signals: 39427
# Length of feature for Temporal Signals: 140
# Number of inputs for Demographics Information: 39427
# Length of feature for Demographics Information: 2
# Counts of labels for In-Hospital Mortality: {0: 35657, 1: 3770}
# Counts of labels for 30-Day Readmission: {0: 37190, 1: 2237}
# Counts of labels for Long Length of Stay: {0: 19739, 1: 19688}

# %%
dict_counts = {
    '0': [counts_mortality[0], counts_readmission[0], counts_length[0]],
    '1': [counts_mortality[1], counts_readmission[1], counts_length[1]]
}
df_counts = pd.DataFrame(dict_counts, index=['In-Hospital Mortality', '30-Day Readmission', 'Long Length of Stay'])

df_counts.plot(kind='bar')
plt.ylabel('Count')
plt.title('Counts of Labels for Prediction Tasks')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %% [markdown]
# ## Model [1]
#
# * Original Paper GitHub Repository: https://github.com/onlyzdd/clinical-fusion
# * Model architecture:
#   * Fusion-CNN:
#     * Clinical notes: Doc2Vec embedding, then 2-layer CNN (with ReLU activation function) and max-pooling
#     * Temporal signals: 2-layer CNN (with ReLU activation function) and max-pooling
#     * Demographic information: One-hot encoding
#     * Patient representation: Concatenation of representations from clinical note, temporal signals, and demographics information.
#   * Fusion-LSTM:
#     * Clinical notes: Doc2Vec embedding, then 2-layer bidirectional LSTM (with ReLU activation function) and max-pooling
#     * Temporal signals: 2-layer bidirectional LSTM (with ReLU activation function) and max-pooling
#     * Demographic information: Concatenation of representations from clinical note, temporal signals, and demographics information.
# * Training objectives:
#     * Loss function: Binary Cross Entropy
#     * Optimizer: Adam
#     * Model is not pretrained
# * Computational requirements:
#     * The authors used a machine with:
#       * 32-core Intel Core 9-9960X CPU
#       * NVIDIA TITAN RTX GPU (576 Tensor Cores, 672 GB/s memory bandwidth)
#     * I used a machine with:
#       * 40-core Intel Xeon Gold 6248 CPU
#       * 2 NVIDIA Volta V100 GPUs (640 Tensor Cores, 900 GB/s memory bandwidth)
# * Metrics descriptions:
#     * Each predictive task (in-hospital mortality, 30-day readmission, long length of stay) is a binary classification problem.
#     * The evaluation metric is AUROC.

# %% [markdown]
# ## Model Frameworks from Original Paper [1]

# %% [markdown]
# !['Fusion-CNN'](./imgs/fusion_cnn.png)

# %% [markdown]
# !['Fusion-LSTM'](./imgs/fusion_lstm.png)

# %% [markdown]
# ## Training

# %% [markdown]
# * Hyperparameters:
#     * Learning rate: 0.0001
#     * Batch size: 64
#     * Hidden size: 200
# * Computational requirements:
#     * Hardware:
#         * The authors used a machine with:
#             * 32-core Intel Core 9-9960X CPU
#             * NVIDIA TITAN RTX GPU (576 Tensor Cores, 672 GB/s memory bandwidth)
#         * I used a machine with:
#             * 40-core Intel Xeon Gold 6248 CPU
#             * 2 NVIDIA Volta V100 GPUs (640 Tensor Cores, 900 GB/s memory bandwidth)
#     * Number of training epochs: 50
#     * Average runtime for each epoch: 15 seconds

# %% [markdown]
# ### Helper functions for training and testing

# %%
'''
FUNCTIONS:
   run_train(): Run training and validation. Best model is saved to '<model>_<task>_<use_unstructure>.ckpt'.
   run_test(): Evaluates on test split. Uploads best model for selected parameters.

PARAMETERS:
   model: 'cnn', 'lstm'
   task: 'mortality', 'readmit', 'llos'
   use_unstructure: 0, 1
      0: Only use structured data (temporal signals and demographics)
      1: Use unstructured data(clinical notes) and structured data
   epochs: Number of epochs for training
   
OUTPUTS:
   Training: Each epoch, training loss, training AUC, validation loss, and validation AUC. Best model (highest validation AUC) is saved to '<model>_<task>_<use_unstructure>.ckpt'. 
   Testing: Testing AUC
'''

def run_train(model, task, use_unstructure, epochs=50):
    command = ["python", "main.py",
               "--model", model,
               "--task", task,
               "--use-unstructure", use_unstructure,
               "--phase", "train",
               "--epochs", epochs
              ]
    output = subprocess.run(command, stdout=subprocess.PIPE)
    print(output.stdout.decode('utf-8'))
    
def run_test(model, task, use_unstructure):
    command = ["python", "main.py",
               "--model", model,
               "--task", task,
               "--use-unstructure", use_unstructure,
               "--phase", "test",
               "--resume", f'{model}_{task}_{use_unstructure}.ckpt'
              ]
    output = subprocess.run(command, stdout=subprocess.PIPE)
    print(output.stdout.decode('utf-8'))

# %%
'''
In-Hospital Mortality: 'mortality'
30-Day Readmission: 'readmit'
Long Length of Stay: 'llos'
'''
list_tasks = ['mortality', 'readmit', 'llos']

num_epochs = "50" # set to 1 to evaluate code functionality

# %% [markdown]
# ### Fusion-CNN

# %%
# Fusion-CNN - Task: In-Hospital Mortality prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[0], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[0], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7021
# LOSS: 0.2342
# valid
# AUC: 0.8016
# LOSS: 0.4819
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.8402
# LOSS: 0.7120
# valid
# AUC: 0.8283
# LOSS: 0.4470
# BEST EPOCH: 3     BEST AUC: 0.8272
#
# START EPOCH:  10
# train
# AUC: 0.8631
# LOSS: 0.3238
# valid
# AUC: 0.8271
# LOSS: 0.4101
# BEST EPOCH: 8     BEST AUC: 0.8302
#
# START EPOCH:  15
# train
# AUC: 0.8770
# LOSS: 0.5870
# valid
# AUC: 0.8297
# LOSS: 0.3970
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  20
# train
# AUC: 0.8966
# LOSS: 0.2207
# valid
# AUC: 0.8288
# LOSS: 0.4146
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  25
# train
# AUC: 0.9073
# LOSS: 0.0895
# valid
# AUC: 0.8282
# LOSS: 0.3730
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  30
# train
# AUC: 0.9206
# LOSS: 0.1876
# valid
# AUC: 0.8293
# LOSS: 0.3841
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  35
# train
# AUC: 0.9295
# LOSS: 0.5618
# valid
# AUC: 0.8249
# LOSS: 0.3925
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  40
# train
# AUC: 0.9356
# LOSS: 0.3176
# valid
# AUC: 0.8257
# LOSS: 0.4155
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# START EPOCH:  45
# train
# AUC: 0.9438
# LOSS: 0.4505
# valid
# AUC: 0.8251
# LOSS: 0.4352
# BEST EPOCH: 13     BEST AUC: 0.8318
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  mortality
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7484
# LOSS: 0.6072
# valid
# AUC: 0.7961
# LOSS: 0.4018
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.8399
# LOSS: 0.3432
# valid
# AUC: 0.8250
# LOSS: 0.3406
# BEST EPOCH: 4     BEST AUC: 0.8277
#
# START EPOCH:  10
# train
# AUC: 0.8831
# LOSS: 0.2254
# valid
# AUC: 0.8166
# LOSS: 0.3141
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  15
# train
# AUC: 0.9319
# LOSS: 0.3281
# valid
# AUC: 0.7833
# LOSS: 0.1968
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  20
# train
# AUC: 0.9630
# LOSS: 1.1771
# valid
# AUC: 0.7732
# LOSS: 0.2491
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  25
# train
# AUC: 0.9773
# LOSS: 0.0307
# valid
# AUC: 0.7656
# LOSS: 0.1865
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  30
# train
# AUC: 0.9856
# LOSS: 0.0295
# valid
# AUC: 0.7607
# LOSS: 0.8920
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  35
# train
# AUC: 0.9909
# LOSS: 0.0728
# valid
# AUC: 0.7589
# LOSS: 0.4811
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  40
# train
# AUC: 0.9919
# LOSS: 0.0356
# valid
# AUC: 0.7605
# LOSS: 0.5288
# BEST EPOCH: 6     BEST AUC: 0.8308
#
# START EPOCH:  45
# train
# AUC: 0.9936
# LOSS: 0.0299
# valid
# AUC: 0.7563
# LOSS: 0.5904
# BEST EPOCH: 6     BEST AUC: 0.8308

# %%
# Fusion-CNN - Task: In-Hospital Mortality prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[0], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[0], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.8356
# LOSS: 0.1867
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  mortality
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.8283
# LOSS: 0.1327

# %%
# Fusion-CNN - Task: 30-Day Readmission prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[1], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[1], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.5598
# LOSS: 0.4900
# valid
# AUC: 0.6604
# LOSS: 0.6804
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.6911
# LOSS: 0.3267
# valid
# AUC: 0.6768
# LOSS: 0.6501
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  10
# train
# AUC: 0.7526
# LOSS: 0.5787
# valid
# AUC: 0.6648
# LOSS: 0.6528
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  15
# train
# AUC: 0.7891
# LOSS: 0.3961
# valid
# AUC: 0.6606
# LOSS: 0.6704
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  20
# train
# AUC: 0.8212
# LOSS: 0.7200
# valid
# AUC: 0.6663
# LOSS: 0.6627
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  25
# train
# AUC: 0.8476
# LOSS: 0.7172
# valid
# AUC: 0.6507
# LOSS: 0.7103
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  30
# train
# AUC: 0.8663
# LOSS: 0.5035
# valid
# AUC: 0.6549
# LOSS: 0.6625
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  35
# train
# AUC: 0.8947
# LOSS: 0.2948
# valid
# AUC: 0.6466
# LOSS: 0.6879
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  40
# train
# AUC: 0.9000
# LOSS: 0.2209
# valid
# AUC: 0.6408
# LOSS: 0.6882
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# START EPOCH:  45
# train
# AUC: 0.9177
# LOSS: 0.1879
# valid
# AUC: 0.6272
# LOSS: 0.6813
# BEST EPOCH: 2     BEST AUC: 0.6839
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  readmit
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.5700
# LOSS: 0.6391
# valid
# AUC: 0.6515
# LOSS: 0.6269
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.6814
# LOSS: 0.6414
# valid
# AUC: 0.6774
# LOSS: 0.6305
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  10
# train
# AUC: 0.7365
# LOSS: 0.2191
# valid
# AUC: 0.6714
# LOSS: 0.5936
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  15
# train
# AUC: 0.8222
# LOSS: 0.2799
# valid
# AUC: 0.6358
# LOSS: 0.6088
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  20
# train
# AUC: 0.9141
# LOSS: 0.2416
# valid
# AUC: 0.6176
# LOSS: 0.9096
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  25
# train
# AUC: 0.9579
# LOSS: 0.0975
# valid
# AUC: 0.6192
# LOSS: 1.3006
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  30
# train
# AUC: 0.9764
# LOSS: 0.0600
# valid
# AUC: 0.5914
# LOSS: 1.4150
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  35
# train
# AUC: 0.9847
# LOSS: 0.4143
# valid
# AUC: 0.5896
# LOSS: 2.1045
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  40
# train
# AUC: 0.9898
# LOSS: 0.0853
# valid
# AUC: 0.5920
# LOSS: 1.9987
# BEST EPOCH: 4     BEST AUC: 0.6852
#
# START EPOCH:  45
# train
# AUC: 0.9912
# LOSS: 0.0263
# valid
# AUC: 0.5882
# LOSS: 1.8422
# BEST EPOCH: 4     BEST AUC: 0.6852

# %%
# Fusion-CNN - Task: 30-Day Readmission prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[1], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[1], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.6274
# LOSS: 0.3239
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  readmit
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.6444
# LOSS: 0.3430

# %%
# Fusion-CNN - Task: Long Length of Stay prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[2], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="cnn", task=list_tasks[2], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  llos
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.6467
# LOSS: 0.5447
# valid
# AUC: 0.7028
# LOSS: 0.7177
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7347
# LOSS: 0.3924
# valid
# AUC: 0.7295
# LOSS: 0.6936
# BEST EPOCH: 4     BEST AUC: 0.7262
#
# START EPOCH:  10
# train
# AUC: 0.7595
# LOSS: 0.8114
# valid
# AUC: 0.7350
# LOSS: 0.7135
# BEST EPOCH: 9     BEST AUC: 0.7333
#
# START EPOCH:  15
# train
# AUC: 0.7765
# LOSS: 0.3427
# valid
# AUC: 0.7350
# LOSS: 0.6907
# BEST EPOCH: 12     BEST AUC: 0.7373
#
# START EPOCH:  20
# train
# AUC: 0.7957
# LOSS: 0.4631
# valid
# AUC: 0.7388
# LOSS: 0.6977
# BEST EPOCH: 19     BEST AUC: 0.7384
#
# START EPOCH:  25
# train
# AUC: 0.8091
# LOSS: 0.4344
# valid
# AUC: 0.7379
# LOSS: 0.7336
# BEST EPOCH: 20     BEST AUC: 0.7388
#
# START EPOCH:  30
# train
# AUC: 0.8230
# LOSS: 0.4684
# valid
# AUC: 0.7392
# LOSS: 0.7521
# BEST EPOCH: 26     BEST AUC: 0.7395
#
# START EPOCH:  35
# train
# AUC: 0.8327
# LOSS: 0.5744
# valid
# AUC: 0.7375
# LOSS: 0.7637
# BEST EPOCH: 26     BEST AUC: 0.7395
#
# START EPOCH:  40
# train
# AUC: 0.8392
# LOSS: 0.5989
# valid
# AUC: 0.7366
# LOSS: 0.7550
# BEST EPOCH: 26     BEST AUC: 0.7395
#
# START EPOCH:  45
# train
# AUC: 0.8471
# LOSS: 0.4909
# valid
# AUC: 0.7381
# LOSS: 0.7728
# BEST EPOCH: 26     BEST AUC: 0.7395
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  llos
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7154
# LOSS: 0.6599
# valid
# AUC: 0.7362
# LOSS: 0.7207
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7690
# LOSS: 0.4390
# valid
# AUC: 0.7559
# LOSS: 0.7143
# BEST EPOCH: 4     BEST AUC: 0.7550
#
# START EPOCH:  10
# train
# AUC: 0.8018
# LOSS: 0.4507
# valid
# AUC: 0.7524
# LOSS: 0.6468
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  15
# train
# AUC: 0.8537
# LOSS: 0.3934
# valid
# AUC: 0.7316
# LOSS: 0.6588
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  20
# train
# AUC: 0.9100
# LOSS: 0.2167
# valid
# AUC: 0.7164
# LOSS: 0.7302
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  25
# train
# AUC: 0.9473
# LOSS: 0.3964
# valid
# AUC: 0.6994
# LOSS: 0.7465
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  30
# train
# AUC: 0.9696
# LOSS: 0.3589
# valid
# AUC: 0.6995
# LOSS: 0.8515
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  35
# train
# AUC: 0.9807
# LOSS: 0.1295
# valid
# AUC: 0.6827
# LOSS: 1.1023
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  40
# train
# AUC: 0.9866
# LOSS: 0.0562
# valid
# AUC: 0.7017
# LOSS: 0.9586
# BEST EPOCH: 6     BEST AUC: 0.7579
#
# START EPOCH:  45
# train
# AUC: 0.9900
# LOSS: 0.0261
# valid
# AUC: 0.6956
# LOSS: 0.9832
# BEST EPOCH: 6     BEST AUC: 0.7579

# %%
# Fusion-CNN - Task: Long Length of Stay prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[2], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="cnn", task=list_tasks[2], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  llos
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.7431
# LOSS: 0.6253
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  cnn
# TASK:  llos
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.7443
# LOSS: 0.4171

# %% [markdown]
# ### Fusion-LSTM

# %%
# Fusion-LSTM - Task: In-Hospital Mortality prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[0], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[0], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7651
# LOSS: 0.4503
# valid
# AUC: 0.8464
# LOSS: 0.4355
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.8765
# LOSS: 0.1669
# valid
# AUC: 0.8798
# LOSS: 0.3069
# BEST EPOCH: 4     BEST AUC: 0.8752
#
# START EPOCH:  10
# train
# AUC: 0.8901
# LOSS: 0.5278
# valid
# AUC: 0.8766
# LOSS: 0.3572
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  15
# train
# AUC: 0.9012
# LOSS: 0.2983
# valid
# AUC: 0.8728
# LOSS: 0.3594
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  20
# train
# AUC: 0.9104
# LOSS: 0.1371
# valid
# AUC: 0.8603
# LOSS: 0.2689
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  25
# train
# AUC: 0.9237
# LOSS: 1.1860
# valid
# AUC: 0.8532
# LOSS: 0.3424
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  30
# train
# AUC: 0.9331
# LOSS: 0.3042
# valid
# AUC: 0.8324
# LOSS: 0.3784
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  35
# train
# AUC: 0.9501
# LOSS: 0.0826
# valid
# AUC: 0.8174
# LOSS: 0.5235
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  40
# train
# AUC: 0.9617
# LOSS: 0.1957
# valid
# AUC: 0.8255
# LOSS: 0.7609
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# START EPOCH:  45
# train
# AUC: 0.9772
# LOSS: 0.3803
# valid
# AUC: 0.7974
# LOSS: 1.0179
# BEST EPOCH: 5     BEST AUC: 0.8798
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.6864
# LOSS: 0.6459
# valid
# AUC: 0.7523
# LOSS: 0.6062
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.8156
# LOSS: 0.5591
# valid
# AUC: 0.8284
# LOSS: 0.3068
# BEST EPOCH: 4     BEST AUC: 0.8144
#
# START EPOCH:  10
# train
# AUC: 0.8338
# LOSS: 0.4823
# valid
# AUC: 0.8282
# LOSS: 0.3362
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  15
# train
# AUC: 0.8445
# LOSS: 0.1769
# valid
# AUC: 0.8228
# LOSS: 0.4043
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  20
# train
# AUC: 0.8581
# LOSS: 0.2058
# valid
# AUC: 0.8217
# LOSS: 0.5550
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  25
# train
# AUC: 0.8715
# LOSS: 1.2505
# valid
# AUC: 0.8225
# LOSS: 0.3343
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  30
# train
# AUC: 0.8878
# LOSS: 0.2970
# valid
# AUC: 0.8103
# LOSS: 0.4352
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  35
# train
# AUC: 0.9082
# LOSS: 0.2668
# valid
# AUC: 0.7967
# LOSS: 0.4782
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  40
# train
# AUC: 0.9247
# LOSS: 0.3041
# valid
# AUC: 0.7918
# LOSS: 0.3600
# BEST EPOCH: 8     BEST AUC: 0.8286
#
# START EPOCH:  45
# train
# AUC: 0.9438
# LOSS: 0.3133
# valid
# AUC: 0.7906
# LOSS: 0.6818
# BEST EPOCH: 8     BEST AUC: 0.8286

# %%
# Fusion-LSTM - Task: In-Hospital Mortality prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[0], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[0], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.8706
# LOSS: 0.1357
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.8292
# LOSS: 0.1722

# %%
# Fusion-LSTM - Task: 30-Day Readmission prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[1], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[1], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.5983
# LOSS: 0.2705
# valid
# AUC: 0.6766
# LOSS: 0.6572
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7063
# LOSS: 0.5203
# valid
# AUC: 0.6774
# LOSS: 0.5997
# BEST EPOCH: 3     BEST AUC: 0.6872
#
# START EPOCH:  10
# train
# AUC: 0.7385
# LOSS: 0.5912
# valid
# AUC: 0.6773
# LOSS: 0.5918
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  15
# train
# AUC: 0.7586
# LOSS: 0.1717
# valid
# AUC: 0.6549
# LOSS: 0.5766
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  20
# train
# AUC: 0.7835
# LOSS: 0.2439
# valid
# AUC: 0.6619
# LOSS: 0.5516
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  25
# train
# AUC: 0.8069
# LOSS: 0.4675
# valid
# AUC: 0.6320
# LOSS: 0.5622
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  30
# train
# AUC: 0.8384
# LOSS: 0.1801
# valid
# AUC: 0.6465
# LOSS: 0.6708
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  35
# train
# AUC: 0.8610
# LOSS: 0.2277
# valid
# AUC: 0.6247
# LOSS: 0.6187
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  40
# train
# AUC: 0.8961
# LOSS: 0.3055
# valid
# AUC: 0.6191
# LOSS: 0.6642
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# START EPOCH:  45
# train
# AUC: 0.9125
# LOSS: 0.2057
# valid
# AUC: 0.5958
# LOSS: 0.7749
# BEST EPOCH: 6     BEST AUC: 0.6943
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.5887
# LOSS: 0.6148
# valid
# AUC: 0.6367
# LOSS: 0.6691
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.6536
# LOSS: 0.3060
# valid
# AUC: 0.6765
# LOSS: 0.6439
# BEST EPOCH: 4     BEST AUC: 0.6669
#
# START EPOCH:  10
# train
# AUC: 0.6840
# LOSS: 0.3198
# valid
# AUC: 0.6840
# LOSS: 0.6195
# BEST EPOCH: 8     BEST AUC: 0.6834
#
# START EPOCH:  15
# train
# AUC: 0.7002
# LOSS: 0.3160
# valid
# AUC: 0.6935
# LOSS: 0.6108
# BEST EPOCH: 12     BEST AUC: 0.6954
#
# START EPOCH:  20
# train
# AUC: 0.7159
# LOSS: 0.3058
# valid
# AUC: 0.7014
# LOSS: 0.6064
# BEST EPOCH: 18     BEST AUC: 0.6985
#
# START EPOCH:  25
# train
# AUC: 0.7354
# LOSS: 0.3741
# valid
# AUC: 0.6920
# LOSS: 0.6217
# BEST EPOCH: 20     BEST AUC: 0.7014
#
# START EPOCH:  30
# train
# AUC: 0.7686
# LOSS: 1.1029
# valid
# AUC: 0.6780
# LOSS: 0.7042
# BEST EPOCH: 20     BEST AUC: 0.7014
#
# START EPOCH:  35
# train
# AUC: 0.8062
# LOSS: 0.2918
# valid
# AUC: 0.6626
# LOSS: 0.7099
# BEST EPOCH: 20     BEST AUC: 0.7014
#
# START EPOCH:  40
# train
# AUC: 0.8483
# LOSS: 0.3484
# valid
# AUC: 0.6716
# LOSS: 0.7589
# BEST EPOCH: 20     BEST AUC: 0.7014
#
# START EPOCH:  45
# train
# AUC: 0.8928
# LOSS: 0.4281
# valid
# AUC: 0.6246
# LOSS: 0.8483
# BEST EPOCH: 20     BEST AUC: 0.7014

# %%
# Fusion-LSTM - Task: 30-Day Readmission prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[1], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[1], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.6720
# LOSS: 0.3150
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.6558
# LOSS: 0.3523

# %%
# Fusion-LSTM - Task: Long Length of Stay prediction
# TRAINING + VALIDATION

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[2], use_unstructure="1", epochs=num_epochs)

# Only use structured data (temporal signals and demographics)
run_train(model="lstm", task=list_tasks[2], use_unstructure="0", epochs=num_epochs)
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7185
# LOSS: 0.7780
# valid
# AUC: 0.7659
# LOSS: 0.7358
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7872
# LOSS: 0.5457
# valid
# AUC: 0.7832
# LOSS: 0.7356
# BEST EPOCH: 4     BEST AUC: 0.7830
#
# START EPOCH:  10
# train
# AUC: 0.8017
# LOSS: 0.5810
# valid
# AUC: 0.7844
# LOSS: 0.7159
# BEST EPOCH: 8     BEST AUC: 0.7853
#
# START EPOCH:  15
# train
# AUC: 0.8123
# LOSS: 0.4397
# valid
# AUC: 0.7824
# LOSS: 0.7296
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  20
# train
# AUC: 0.8237
# LOSS: 0.5232
# valid
# AUC: 0.7805
# LOSS: 0.7645
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  25
# train
# AUC: 0.8361
# LOSS: 0.5443
# valid
# AUC: 0.7787
# LOSS: 0.7714
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  30
# train
# AUC: 0.8511
# LOSS: 0.3544
# valid
# AUC: 0.7769
# LOSS: 0.7857
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  35
# train
# AUC: 0.8692
# LOSS: 0.2851
# valid
# AUC: 0.7655
# LOSS: 0.8537
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  40
# train
# AUC: 0.8911
# LOSS: 0.4585
# valid
# AUC: 0.7511
# LOSS: 0.9666
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# START EPOCH:  45
# train
# AUC: 0.9112
# LOSS: 0.2944
# valid
# AUC: 0.7554
# LOSS: 1.2226
# BEST EPOCH: 14     BEST AUC: 0.7855
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  0
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.6852
# LOSS: 0.6019
# valid
# AUC: 0.7244
# LOSS: 0.7140
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7445
# LOSS: 0.5360
# valid
# AUC: 0.7515
# LOSS: 0.7130
# BEST EPOCH: 4     BEST AUC: 0.7476
#
# START EPOCH:  10
# train
# AUC: 0.7577
# LOSS: 0.4489
# valid
# AUC: 0.7585
# LOSS: 0.7156
# BEST EPOCH: 8     BEST AUC: 0.7554
#
# START EPOCH:  15
# train
# AUC: 0.7644
# LOSS: 0.4840
# valid
# AUC: 0.7606
# LOSS: 0.7174
# BEST EPOCH: 11     BEST AUC: 0.7611
#
# START EPOCH:  20
# train
# AUC: 0.7724
# LOSS: 0.4896
# valid
# AUC: 0.7553
# LOSS: 0.6684
# BEST EPOCH: 16     BEST AUC: 0.7634
#
# START EPOCH:  25
# train
# AUC: 0.7800
# LOSS: 0.4693
# valid
# AUC: 0.7683
# LOSS: 0.6753
# BEST EPOCH: 22     BEST AUC: 0.7682
#
# START EPOCH:  30
# train
# AUC: 0.7905
# LOSS: 0.8044
# valid
# AUC: 0.7649
# LOSS: 0.6924
# BEST EPOCH: 25     BEST AUC: 0.7683
#
# START EPOCH:  35
# train
# AUC: 0.8076
# LOSS: 0.6609
# valid
# AUC: 0.7587
# LOSS: 0.6740
# BEST EPOCH: 25     BEST AUC: 0.7683
#
# START EPOCH:  40
# train
# AUC: 0.8305
# LOSS: 0.3299
# valid
# AUC: 0.7440
# LOSS: 0.7205
# BEST EPOCH: 25     BEST AUC: 0.7683
#
# START EPOCH:  45
# train
# AUC: 0.8620
# LOSS: 0.2058
# valid
# AUC: 0.7416
# LOSS: 0.8779
# BEST EPOCH: 25     BEST AUC: 0.7683

# %%
# Fusion-LSTM - Task: Long Length of Stay prediction
# TESTING

# Use unstructured clinical notes with structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[2], use_unstructure="1")

# Only use structured data (temporal signals and demographics)
run_test(model="lstm", task=list_tasks[2], use_unstructure="0")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.7841
# LOSS: 0.4547
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  0
# test
# AUC: 0.7557
# LOSS: 0.4205

# %% [markdown]
# # Results and Evaluation

# %% [markdown]
# * Results outputs:
#     * Training: Each epoch, training loss, training AUC, validation loss, and validation AUC. Best model (highest validation AUC) is saved to "MODEL_TASK_USE-UNSTRUCTURE.ckpt".
#     * Testing: Testing AUC
# * Metrics descriptions:
#     * Each predictive task (in-hospital mortality, 30-day readmission, long length of stay) is a binary classification problem.
#     * The evaluation metric is AUROC.

# %% [markdown]
# ## Training and Validation Losses

# %%
def plot_loss(model, task):
    '''
      model: 'cnn', 'lstm'
      task: 'mortality', 'readmit', 'llos'
      
    '''
    
    # load dataframes with metrics for models with and without unstructured data
    model_0 = pd.read_csv(f'./metrics/{model}_{task}_0.csv')
    model_1 = pd.read_csv(f'./metrics/{model}_{task}_1.csv')
    
    # plot training loss and validation loss for models with and without unstructured data
    plt.figure(figsize=(15, 7))
    plt.plot(model_0['epoch'], model_0['train_loss'], marker='o', label='Training Loss (Only Structured)')
    plt.plot(model_0['epoch'], model_0['val_loss'], marker='o', linestyle='--', label='Validation Loss (Only Structured)')
    plt.plot(model_1['epoch'], model_1['train_loss'], marker='s', label='Training Loss (Structured + Unstructured)')
    plt.plot(model_1['epoch'], model_1['val_loss'], marker='s', linestyle='--', label='Validation Loss (Structured + Unstructured)')
    plt.title(f'Training and Validation Loss - {model} - {task}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    plt.show()
    
list_tasks = ['mortality', 'readmit', 'llos']

# %%
# Losses for Fusion-CNN
for task in list_tasks:
    plot_loss('cnn', task)

# %%
# Losses for Fusion-LSTM
for task in list_tasks:
    plot_loss('lstm', task)

# %% [markdown]
# ## Training and Validation AUCs

# %%
def plot_auc(model, task):
    '''
      model: 'cnn', 'lstm'
      task: 'mortality', 'readmit', 'llos'
      
    '''
    
    # load dataframes with metrics for models with and without unstructured data
    model_0 = pd.read_csv(f'./metrics/{model}_{task}_0.csv')
    model_1 = pd.read_csv(f'./metrics/{model}_{task}_1.csv')
    
    # plot training loss and validation loss for models with and without unstructured data
    plt.figure(figsize=(15, 7))
    plt.plot(model_0['epoch'], model_0['train_auc'], marker='o', label='Training AUC (Only Structured)')
    plt.plot(model_0['epoch'], model_0['val_auc'], marker='o', linestyle='--', label='Validation AUC (Only Structured)')
    plt.plot(model_1['epoch'], model_1['train_auc'], marker='s', label='Training AUC (Structured + Unstructured)')
    plt.plot(model_1['epoch'], model_1['val_auc'], marker='s', linestyle='--', label='Validation AUC (Structured + Unstructured)')
    plt.title(f'Training and Validation AUC - {model} - {task}')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()
    plt.grid(True)
    
    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    plt.show()
    
list_tasks = ['mortality', 'readmit', 'llos']

# %%
# AUCs for Fusion-CNN
for task in list_tasks:
    plot_auc('cnn', task)

# %%
# AUCs for Fusion-LSTM
for task in list_tasks:
    plot_auc('lstm', task)

# %% [markdown]
# ## Testing AUCs

# %%
# Load dataframe with testing auc values
metrics_testing = pd.read_csv('./metrics/metrics_testing.csv')
metrics_testing['difference'] = np.abs(metrics_testing['auc'] - metrics_testing['paper auc'])
metrics_testing
# Out:
#      model         task  use_unstructure     auc  paper auc  difference
# 0    'cnn'  'mortality'                1  0.8356      0.870      0.0344
# 1    'cnn'  'mortality'                0  0.8283      0.827      0.0013
# 2    'cnn'    'readmit'                1  0.6274      0.671      0.0436
# 3    'cnn'    'readmit'                0  0.6444      0.657      0.0126
# 4    'cnn'       'llos'                1  0.7431      0.784      0.0409
# 5    'cnn'       'llos'                0  0.7443      0.748      0.0037
# 6   'lstm'  'mortality'                1  0.8706      0.871      0.0004
# 7   'lstm'  'mortality'                0  0.8292      0.837      0.0078
# 8   'lstm'    'readmit'                1  0.6720      0.674      0.0020
# 9   'lstm'    'readmit'                0  0.6558      0.653      0.0028
# 10  'lstm'       'llos'                1  0.7841      0.778      0.0061
# 11  'lstm'       'llos'                0  0.7557      0.757      0.0013

# %%
# Create combinations of models, tasks, and datasets
metrics_testing['combination'] = metrics_testing['model'] + '_' + metrics_testing['use_unstructure'].astype(str)
metrics_testing['task_model_unstructure'] = metrics_testing['task'] + '_' + metrics_testing['combination']

# Plot bar graph
plt.figure(figsize=(12, 8))
sns.barplot(x='task', y='auc', hue='combination', data=metrics_testing)
plt.xticks(rotation=45)
plt.xlabel('Task')
plt.ylabel('AUC')
plt.legend(title='<model>_<use-unstructure>')
plt.title('Test Results - Reproduction')
plt.tight_layout()
plt.show()

# %%
# Create combinations of models, tasks, and datasets
metrics_testing['combination'] = metrics_testing['model'] + '_' + metrics_testing['use_unstructure'].astype(str)
metrics_testing['task_model_unstructure'] = metrics_testing['task'] + '_' + metrics_testing['combination']

# Plot bar graph
plt.figure(figsize=(12, 8))
sns.barplot(x='task', y='paper auc', hue='combination', data=metrics_testing)
plt.xticks(rotation=45)
plt.xlabel('Task')
plt.ylabel('AUC')
plt.legend(title='<model>_<use-unstructure>')
plt.title('Test Results - Original Paper')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model comparison

# %% [markdown]
# * Fusion-CNN versus Fusion-LSTM
#   * Fusion-LSTM with unstructured data performed the best on all the prediction tasks
#   * In-Hospital Mortality: Fusion-LSTM with unstructured data had the best test AUC with 0.8706
#   * 30-Day Readmission: Fusion-LSTM with unstructured data had the best test AUC with 0.6720
#   * Long Length of Stay: Fusion-CNN with unstructured data had the best test AUC with 0.7841
# * Ablation study: With unstructured versus without unstructured
#   * With Fusion-CNNs, except for the 30-day readmission task, the additional of unstructured data improved the models' performances
#   * With Fusion-LSTMs, for every task, the additional of unstructured data improvied the models' performances
# * Deep Learning Models versus Baseline Models
#   * From the results in the paper, the deep learning models slightly outperformed the baseline models in this reproduction
#   * In-Hospital Mortality: From the paper, logistic regression had the best test AUC with 0.86 (versus Fusion-LSTM with unstructured data: AUC = 0.8706)
#   * 30-Day Readmission: From the paper, logistic regression had the best test AUC with 0.66 (versus Fusion-LSTM with unstructured data: AUC = 0.6720)
#   * Long Length of Stay: From the paper, logistic regression had the best test AUC with 0.77 (versus Fusion-LSTM with unstructured data: AUC = 0.7841)

# %% [markdown]
# # Experiment Beyond Paper

# %% [markdown]
# Use the best model (Fusion-LSTM with unstructured data) and reduce the embedding size from 200 to 50.

# %%
'''
FUNCTIONS:
   run_train_experiment(): Run training and validation. Best model is saved to '<model>_<task>_<use_unstructure>_experiment.ckpt'.
   run_test_experiment(): Evaluates on test split. Uploads best model for selected parameters.

PARAMETERS:
   model: 'cnn', 'lstm'
   task: 'mortality', 'readmit', 'llos'
   use_unstructure: 0, 1
      0: Only use structured data (temporal signals and demographics)
      1: Use unstructured data(clinical notes) and structured data
   epochs: Number of epochs for training
   
OUTPUTS:
   Training: Each epoch, training loss, training AUC, validation loss, and validation AUC. Best model (highest validation AUC) is saved to '<model>_<task>_<use_unstructure>.ckpt'. 
   Testing: Testing AUC
'''

def run_train_experiment(model, task, use_unstructure, epochs=50):
    command = ["python", "main.py",
               "--model", model,
               "--task", task,
               "--use-unstructure", use_unstructure,
               "--phase", "train",
               "--epochs", epochs,
               "--embed-size", "50"
              ]
    output = subprocess.run(command, stdout=subprocess.PIPE)
    print(output.stdout.decode('utf-8'))
    
def run_test_experiment(model, task, use_unstructure):
    command = ["python", "main.py",
               "--model", model,
               "--task", task,
               "--use-unstructure", use_unstructure,
               "--phase", "test",
               "--resume", f'{model}_{task}_{use_unstructure}.ckpt',
               "--embed-size", "50"
              ]
    output = subprocess.run(command, stdout=subprocess.PIPE)
    print(output.stdout.decode('utf-8'))
    
'''
In-Hospital Mortality: 'mortality'
30-Day Readmission: 'readmit'
Long Length of Stay: 'llos'
'''
list_tasks = ['mortality', 'readmit', 'llos']

num_epochs = "50" # set to 1 to evaluate code functionality

# %%
# Fusion-LSTM with unstructured data - Task: In-Hospital Mortality prediction

# TRAINING + VALIDATION
run_train_experiment(model="lstm", task=list_tasks[0], use_unstructure="1", epochs=num_epochs)

# TESTING
run_test_experiment(model="lstm", task=list_tasks[0], use_unstructure="1")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7613
# LOSS: 0.2766
# valid
# AUC: 0.8443
# LOSS: 0.4175
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.8745
# LOSS: 0.2250
# valid
# AUC: 0.8752
# LOSS: 0.3411
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  10
# train
# AUC: 0.8887
# LOSS: 1.2692
# valid
# AUC: 0.8758
# LOSS: 0.3463
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  15
# train
# AUC: 0.9009
# LOSS: 0.3948
# valid
# AUC: 0.8694
# LOSS: 0.3133
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  20
# train
# AUC: 0.9109
# LOSS: 0.7123
# valid
# AUC: 0.8631
# LOSS: 0.3375
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  25
# train
# AUC: 0.9235
# LOSS: 0.2660
# valid
# AUC: 0.8512
# LOSS: 0.2796
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  30
# train
# AUC: 0.9339
# LOSS: 0.1882
# valid
# AUC: 0.8465
# LOSS: 0.2769
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  35
# train
# AUC: 0.9506
# LOSS: 0.4263
# valid
# AUC: 0.8406
# LOSS: 0.2466
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  40
# train
# AUC: 0.9653
# LOSS: 0.0411
# valid
# AUC: 0.8338
# LOSS: 0.4706
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# START EPOCH:  45
# train
# AUC: 0.9788
# LOSS: 0.2798
# valid
# AUC: 0.8251
# LOSS: 0.4316
# BEST EPOCH: 4     BEST AUC: 0.8779
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  mortality
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.8683
# LOSS: 0.1712

# %%
# Fusion-LSTM with unstructured data - Task: 30-Day Readmission prediction

# TRAINING + VALIDATION
run_train_experiment(model="lstm", task=list_tasks[1], use_unstructure="1", epochs=num_epochs)

# TESTING
run_test_experiment(model="lstm", task=list_tasks[1], use_unstructure="1")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.6049
# LOSS: 0.3810
# valid
# AUC: 0.6854
# LOSS: 0.6501
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7076
# LOSS: 0.4331
# valid
# AUC: 0.6845
# LOSS: 0.6142
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  10
# train
# AUC: 0.7355
# LOSS: 0.4105
# valid
# AUC: 0.6811
# LOSS: 0.5878
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  15
# train
# AUC: 0.7544
# LOSS: 0.2691
# valid
# AUC: 0.6570
# LOSS: 0.5708
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  20
# train
# AUC: 0.7808
# LOSS: 0.2274
# valid
# AUC: 0.6384
# LOSS: 0.5354
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  25
# train
# AUC: 0.7977
# LOSS: 0.2924
# valid
# AUC: 0.6569
# LOSS: 0.5725
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  30
# train
# AUC: 0.8294
# LOSS: 0.3941
# valid
# AUC: 0.6450
# LOSS: 0.5012
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  35
# train
# AUC: 0.8581
# LOSS: 0.2775
# valid
# AUC: 0.6610
# LOSS: 0.4640
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  40
# train
# AUC: 0.8889
# LOSS: 0.5869
# valid
# AUC: 0.6346
# LOSS: 0.5628
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# START EPOCH:  45
# train
# AUC: 0.9161
# LOSS: 0.5499
# valid
# AUC: 0.6148
# LOSS: 0.7292
# BEST EPOCH: 1     BEST AUC: 0.6965
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  readmit
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.6596
# LOSS: 0.3477

# %%
# Fusion-LSTM with unstructured data - Task: Long Length of Stay prediction

# TRAINING + VALIDATION
run_train_experiment(model="lstm", task=list_tasks[2], use_unstructure="1", epochs=num_epochs)

# TESTING
run_test_experiment(model="lstm", task=list_tasks[2], use_unstructure="1")
# Out:
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  1
# NUMBER OF EPOCHS:  50
#
# START EPOCH:  0
# train
# AUC: 0.7201
# LOSS: 0.4129
# valid
# AUC: 0.7653
# LOSS: 0.7540
# BEST EPOCH: 0     BEST AUC: 0.0000
#
# START EPOCH:  5
# train
# AUC: 0.7886
# LOSS: 0.6040
# valid
# AUC: 0.7794
# LOSS: 0.7653
# BEST EPOCH: 4     BEST AUC: 0.7805
#
# START EPOCH:  10
# train
# AUC: 0.8012
# LOSS: 0.6491
# valid
# AUC: 0.7838
# LOSS: 0.7661
# BEST EPOCH: 8     BEST AUC: 0.7843
#
# START EPOCH:  15
# train
# AUC: 0.8133
# LOSS: 0.4734
# valid
# AUC: 0.7836
# LOSS: 0.7616
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  20
# train
# AUC: 0.8252
# LOSS: 0.4690
# valid
# AUC: 0.7792
# LOSS: 0.7910
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  25
# train
# AUC: 0.8375
# LOSS: 0.2558
# valid
# AUC: 0.7812
# LOSS: 0.7896
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  30
# train
# AUC: 0.8542
# LOSS: 0.9328
# valid
# AUC: 0.7726
# LOSS: 0.7751
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  35
# train
# AUC: 0.8709
# LOSS: 0.3030
# valid
# AUC: 0.7591
# LOSS: 0.8102
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  40
# train
# AUC: 0.8922
# LOSS: 0.4776
# valid
# AUC: 0.7570
# LOSS: 1.0014
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# START EPOCH:  45
# train
# AUC: 0.9161
# LOSS: 0.6886
# valid
# AUC: 0.7364
# LOSS: 1.1223
# BEST EPOCH: 11     BEST AUC: 0.7844
#
# Use the last 24 collections data
# Use the last 24 collections data
# Use the last 24 collections data
#
# MODEL:  lstm
# TASK:  llos
# USE_UNSTRUCTURE:  1
# test
# AUC: 0.7819
# LOSS: 0.4705

# %% [markdown]
# ## Results from experiment

# %%
# Losses from experiment

list_tasks = ['mortality', 'readmit', 'llos']
model = 'experiment-lstm'

for task in list_tasks:
    
    # load dataframes with metrics for models
    model_1 = pd.read_csv(f'./metrics/{model}_{task}_1.csv')
    
    # plot training loss and validation loss for models
    plt.figure(figsize=(15, 7))
    plt.plot(model_1['epoch'], model_1['train_loss'], marker='s', label='Training Loss (Structured + Unstructured)')
    plt.plot(model_1['epoch'], model_1['val_loss'], marker='s', linestyle='--', label='Validation Loss (Structured + Unstructured)')
    plt.title(f'Training and Validation Loss - {model} - {task}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    plt.show()

# %%
# Losses from experiment

list_tasks = ['mortality', 'readmit', 'llos']
model = 'experiment-lstm'

for task in list_tasks:
    
    # load dataframes with metrics for models
    model_1 = pd.read_csv(f'./metrics/{model}_{task}_1.csv')
    
    # plot training loss and validation loss for models
    plt.figure(figsize=(15, 7))
    plt.plot(model_1['epoch'], model_1['train_auc'], marker='s', label='Training AUC (Structured + Unstructured)')
    plt.plot(model_1['epoch'], model_1['val_auc'], marker='s', linestyle='--', label='Validation AUC (Structured + Unstructured)')
    plt.title(f'Training and Validation AUC - {model} - {task}')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()
    plt.grid(True)
    
    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    plt.show()

# %% [markdown]
# ## Comparison from experiment

# %%
# Load dataframe with testing auc values for Fusion-LSTM models trained with unstructured data 
# with embedding sizes of 200 and 50
metrics_experiment = pd.read_csv('./metrics/metrics_experiment.csv')
metrics_experiment['difference (200-50)'] = np.abs(metrics_experiment['auc (200)'] - metrics_experiment['auc (50)'])
metrics_experiment
# Out:
#           task  auc (200)  auc (50)  difference (200-50)
# 0  'mortality'     0.8706    0.8683               0.0023
# 1    'readmit'     0.6720    0.6596               0.0124
# 2       'llos'     0.7841    0.7819               0.0022

# %%
ax = metrics_experiment[['auc (200)', 'auc (50)']].plot(kind='bar')
plt.xlabel('Task')
plt.ylabel('AUC')
ax.set_xticklabels(list(metrics_experiment['task']))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Discussion
#
# * **Make assessment that the paper is reproducible or not.**
#   * This paper is reproducible and the results are positive. The deep learning models (Fusion-CNN and Fusion-LSTM) performed slightly better on the testing data after training for 50 epochs compared to the baseline models. The original paper had the Fusion-LSTM model trained with unstructured data performing best on the in-hospital mortality and the 30-day readmission prediction tasks, while the Fusion-CNN model trained with unstructured data performed best on the long length of stay prediction task. In the reproduction, the Fusion-LSTM model trained with unstructured data performed the best on all the prediction tasks. There is a difference in the results for the long length of stay prediction task The difference might be related to the initialized weights. The model was not pre-trained, but the random initialization could result in slight differences in performance after training. The results for the other tasks were reproduced. The ablation study showed that for all the models, removing the unstructured data and only training on the structured data reduced the performance of the models. Their hypotheses were supported by the reproduction. The addition of unstructured clinical notes improved the performance of the models. And, the deep learning models performed better than the baseline methods.
#
# * **Describe “What was easy” and “What was difficult” during the reproduction.**
#   * The code and the GitHub repository were well-documented and that made it easier for reproduction. It was easy to obtain the dataset and preprocess it for training the models. The structure of the models was easily understandable from the code. The old code/packages and porting the code to a Jupyter Notebook was difficult. It was difficult to create an environment that worked for the code, even with the specified package versions. I had to iterate with versions to get an environment that worked with my CUDA and GPU too. Also, I had to create a wrapper to initialize and train the models in a Jupyter notebook. These steps were difficult and took lots of time.
#
# * **Make suggestions to the author or other reproducers on how to improve the reproducibility.**
#   * A suggestion to improve reproducibility would be to include an environment yml file for recreating the environment that worked with the code. Or having a Docker file would help with reproducibility as code gets older. I included a yml file for creating a Conda environment and would recommend that other reproducers use it for reproducing this paper.

# %% [markdown]
# * **Other thoughts:**
#    * The loss curves and the AUC curves in the reproduction are interesting. The AUC flattens early in the training and the losses for the validation set increase in some of the prediction tasks. This is indicative of overfitting and future work could include using regularization and smaller embedding sizes. The loss curves and the AUC curves were not shown in the original paper, so it's possible that they had the same issues as well.
# * **Discussion about the experiment:**
#    * The experiment beyond the paper was to train the best performing model (Fusion-LSTM with unstructured data), but reduce the embedding size from 200 to 50. The loss curves still showed overfitting, so smaller sizes and regularization still need to be implemented. The results showed very small reduction in performance for the the test AUC (~0.01). This means that the runtime and computational requirements could be reduced without significant impact to the predictive performance.

# %% [markdown]
# # References
#
# 1. Zhang, D., Yin, C., Zeng, J., Yuan, X., & Zhang, P. (2020). Combining structured and unstructured data for predictive models: a deep learning approach. *BMC Medical Informatics and Decision Making*, *20*, 1-11.
# 2. Caruana, R., Lou, Y., Gehrke, J., Koch, P., Sturm, M., & Elhadad, N. (2015, August). Intelligible models for healthcare: Predicting pneumonia risk and hospital 30-day readmission. In *Proceedings of the 21th ACM SIGKDD International Conference on Knowledge Discovery and Data Mining* (pp. 1721-1730).
# 3. Tang, F., Xiao, C., Wang, F., & Zhou, J. (2018). Predictive modeling in urgent care: a comparative study of machine learning approaches. *JAMIA Open*, *1*(1), 87-98.
